# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('company_sales_data.csv')
data
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %%
x=data['month_number']
y=data['total_profit']
plt.plot(x,y,color='green', marker = '+',markersize =12)
plt.show()

# %%
plt.plot(data["month_number"],data["facecream"],label="facecream")
plt.plot(data["month_number"],data["facewash"],label="facewash")
plt.plot(data["month_number"],data["toothpaste"],label="toothpaste")
plt.plot(data["month_number"],data["bathingsoap"],label="bathingsoap")
plt.plot(data["month_number"],data["shampoo"],label="shampoo")
plt.plot(data["month_number"],data["moisturizer"],label="moiturizer")
plt.title("Line plot")
plt.xlabel('sales')
plt.ylabel('profit')
plt.legend()
plt.show()

# %%
plt.bar(data["month_number"],data["facecream"],label="facecream")
plt.bar(data["month_number"],data["facewash"],label="facewash")
plt.bar(data["month_number"],data["toothpaste"],label="toothpaste")
plt.bar(data["month_number"],data["bathingsoap"],label="bathingsoap")
plt.bar(data["month_number"],data["shampoo"],label="shampoo")
plt.bar(data["month_number"],data["moisturizer"],label="moiturizer")
plt.title("Line plot")
plt.xlabel('Month no.')
plt.ylabel('Total profit')
plt.legend()
plt.show()
